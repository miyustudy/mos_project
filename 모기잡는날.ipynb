# %%
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

#warning
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('master_data_ver2.csv', encoding='euc-kr',index_col = 'date')
data
# Out:
#              num   mos  mean_temp  min_temp  max_temp  rain  wind   hum  \
# date
# 2015-05-01     1  2783       21.0      15.9      27.2   NaN   2.5  58.8
# 2015-05-02     2  2783       20.7      15.8      26.0   0.5   2.1  64.4
# 2015-05-03     3  2998       18.3      17.1      19.6   3.5   2.1  90.4
# 2015-05-04     4  3392       16.1      12.5      20.1   NaN   4.2  45.9
# 2015-05-05     5  3137       14.2       8.3      19.9   NaN   3.4  37.9
# ...          ...   ...        ...       ...       ...   ...   ...   ...
# 2021-10-27  1284   669       13.4       9.8      18.1   0.0   2.2  63.4
# 2021-10-28  1285   691       12.7       7.1      20.0   NaN   1.4  54.6
# 2021-10-29  1286   765       14.6      10.5      20.6   NaN   2.0  55.9
# 2021-10-30  1287   829       13.8      11.0      18.0   NaN   1.6  62.4
# 2021-10-31  1288   745       14.1       9.2      20.3   0.7   1.6  73.3
#
#                atm   sun  cloud  g_temp  b_eva  s_eva
# date
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#              num   mos  mean_temp  min_temp  max_temp  rain  wind   hum  \
# date
# 2015-05-01     1  2783       21.0      15.9      27.2   NaN   2.5  58.8
# 2015-05-02     2  2783       20.7      15.8      26.0   0.5   2.1  64.4
# 2015-05-03     3  2998       18.3      17.1      19.6   3.5   2.1  90.4
# 2015-05-04     4  3392       16.1      12.5      20.1   NaN   4.2  45.9
# 2015-05-05     5  3137       14.2       8.3      19.9   NaN   3.4  37.9
# ...          ...   ...        ...       ...       ...   ...   ...   ...
# 2021-10-27  1284   669       13.4       9.8      18.1   0.0   2.2  63.4
# 2021-10-28  1285   691       12.7       7.1      20.0   NaN   1.4  54.6
# 2021-10-29  1286   765       14.6      10.5      20.6   NaN   2.0  55.9
# 2021-10-30  1287   829       13.8      11.0      18.0   NaN   1.6  62.4
# 2021-10-31  1288   745       14.1       9.2      20.3   0.7   1.6  73.3
#
#                atm   sun  cloud  g_temp  b_eva  s_eva
# date
# ...

# %%
df.isna()
# Out:
#               num    mos  mean_temp  min_temp  max_temp   rain   wind    hum  \
# date
# 2015-05-01  False  False      False     False     False   True  False  False
# 2015-05-02  False  False      False     False     False  False  False  False
# 2015-05-03  False  False      False     False     False  False  False  False
# 2015-05-04  False  False      False     False     False   True  False  False
# 2015-05-05  False  False      False     False     False   True  False  False
# ...           ...    ...        ...       ...       ...    ...    ...    ...
# 2021-10-27  False  False      False     False     False  False  False  False
# 2021-10-28  False  False      False     False     False   True  False  False
# 2021-10-29  False  False      False     False     False   True  False  False
# 2021-10-30  False  False      False     False     False   True  False  False
# 2021-10-31  False  False      False     False     False  False  False  False
#
# ...

# %%
df['rain']= df['rain'].fillna(0)

# %%
df = df.dropna()

# %%
df = df.drop(['num'],axis=1)

# %%
df
# Out:
#              mos  mean_temp  min_temp  max_temp  rain  wind   hum     atm  \
# date
# 2015-05-01  2783       21.0      15.9      27.2   0.0   2.5  58.8  1003.3
# 2015-05-02  2783       20.7      15.8      26.0   0.5   2.1  64.4  1001.7
# 2015-05-03  2998       18.3      17.1      19.6   3.5   2.1  90.4   997.2
# 2015-05-04  3392       16.1      12.5      20.1   0.0   4.2  45.9   998.9
# 2015-05-05  3137       14.2       8.3      19.9   0.0   3.4  37.9  1001.3
# ...          ...        ...       ...       ...   ...   ...   ...     ...
# 2021-10-27   669       13.4       9.8      18.1   0.0   2.2  63.4  1009.2
# 2021-10-28   691       12.7       7.1      20.0   0.0   1.4  54.6  1013.1
# 2021-10-29   765       14.6      10.5      20.6   0.0   2.0  55.9  1014.5
# 2021-10-30   829       13.8      11.0      18.0   0.0   1.6  62.4  1013.5
# 2021-10-31   745       14.1       9.2      20.3   0.7   1.6  73.3  1013.4
#
#              sun  cloud  g_temp  b_eva  s_eva
# date
# ...

# %%
del2 = df[df['mos'].str.isnumeric() == 0].index
df = df.drop(del2, inplace = False)
df['mos'].describe()

df['mos'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1227 entries, 2015-05-01 to 2021-10-31
# Series name: mos
# Non-Null Count  Dtype
# --------------  -----
# 1227 non-null   object
# dtypes: object(1)
# memory usage: 19.2+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1227 entries, 2015-05-01 to 2021-10-31
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   mos        1227 non-null   object
#  1   mean_temp  1227 non-null   float64
#  2   min_temp   1227 non-null   float64
#  3   max_temp   1227 non-null   float64
#  4   rain       1227 non-null   float64
#  5   wind       1227 non-null   float64
#  6   hum        1227 non-null   float64
#  7   atm        1227 non-null   float64
#  8   sun        1227 non-null   float64
#  9   cloud      1227 non-null   float64
#  10  g_temp     1227 non-null   float64
#  11  b_eva      1227 non-null   float64
#  12  s_eva      1227 non-null   float64
# dtypes: float64(12), object(1)
# memory usage: 134.2+ KB

# %%
df
# Out:
#              mos  mean_temp  min_temp  max_temp  rain  wind   hum     atm  \
# date
# 2015-05-01  2783       21.0      15.9      27.2   0.0   2.5  58.8  1003.3
# 2015-05-02  2783       20.7      15.8      26.0   0.5   2.1  64.4  1001.7
# 2015-05-03  2998       18.3      17.1      19.6   3.5   2.1  90.4   997.2
# 2015-05-04  3392       16.1      12.5      20.1   0.0   4.2  45.9   998.9
# 2015-05-05  3137       14.2       8.3      19.9   0.0   3.4  37.9  1001.3
# ...          ...        ...       ...       ...   ...   ...   ...     ...
# 2021-10-27   669       13.4       9.8      18.1   0.0   2.2  63.4  1009.2
# 2021-10-28   691       12.7       7.1      20.0   0.0   1.4  54.6  1013.1
# 2021-10-29   765       14.6      10.5      20.6   0.0   2.0  55.9  1014.5
# 2021-10-30   829       13.8      11.0      18.0   0.0   1.6  62.4  1013.5
# 2021-10-31   745       14.1       9.2      20.3   0.7   1.6  73.3  1013.4
#
#              sun  cloud  g_temp  b_eva  s_eva
# date
# ...

# %%
df['mos'] = df['mos'].astype('int')

# %%
stocks = px.data.stocks()
stocks
# Out:
#            date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0    2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1    2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2    2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3    2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4    2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708
# ..          ...       ...       ...       ...       ...       ...       ...
# 100  2019-12-02  1.216280  1.546914  1.425061  1.075997  1.463641  1.720717
# 101  2019-12-09  1.222821  1.572286  1.432660  1.038855  1.421496  1.752239
# 102  2019-12-16  1.224418  1.596800  1.453455  1.104094  1.604362  1.784896
# 103  2019-12-23  1.226504  1.656000  1.521226  1.113728  1.567170  1.802472
# 104  2019-12-30  1.213014  1.678000  1.503360  1.098475  1.540883  1.788185
#
# [105 rows x 7 columns]

# %%
df_sorted_by_values = df.sort_values(by='mos' ,ascending=False)

# %%
df_sorted_by_values.head()
# Out:
#               mos  mean_temp  min_temp  max_temp  rain  wind   hum     atm  \
# date
# 2016-06-06  26441       23.3      20.8      28.4   0.0   2.3  49.1  1002.4
# 2016-10-03  19458       22.7      19.6      27.9   6.5   2.7  73.3   999.9
# 2016-08-12  19309       30.4      26.4      35.9   0.0   2.0  68.3   997.8
# 2016-10-04  16871       22.0      15.6      29.0   0.0   2.4  58.9  1004.9
# 2015-05-29  16214       23.8      18.5      29.8   0.0   2.5  36.8   997.2
#
#              sun  cloud  g_temp  b_eva  s_eva
# date
# 2016-06-06  15.6    7.4    28.0    5.2    6.2
# 2016-10-03  14.5    4.0    23.6    3.1    4.4
# 2016-08-12  19.6    1.8    37.5    4.5    6.4
# 2016-10-04  16.9    0.9    22.4    4.6    6.6
# 2015-05-29  18.4    7.3    30.4    4.5    5.4

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data = data.corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
ax = sns.heatmap(df)
plt.title('Heatmap of Flight by seaborn', fontsize=20)
plt.show()

# %%
sns.set(style='whitegrid') # whitegrid = 배경에 하얀 선
sns.pairplot(df)
plt.show()
